# %%
import pandas as pd
import numpy as np
from skimpy import clean_columns
from pickle import load
import os
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import f1_score, balanced_accuracy_score, roc_auc_score,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
from sklearn.metrics import confusion_matrix

# %%
## Load the training and validation data
train_df = pd.read_csv("data/heart_failure/train_val_split.csv").pipe(
        clean_columns)
X_train = train_df.drop(columns=["heart_disease"], axis=1)
X_train = X_train.drop(366)
y_train = train_df["heart_disease"]
y_train = y_train[X_train.index]

# create categorical variable for cholesterol level
X_train["chol_level"] = pd.cut(
    X_train["cholesterol"],
    bins=[-1, 100, 200, 240, 1000],
    labels=["imputed", "normal", "borderline", "high"]
)

# %%
## Load the test data
test_df = pd.read_csv("data/heart_failure/test_split.csv").pipe(clean_columns)
X_test = test_df.drop(columns=["heart_disease"], axis=1)
# create categorical variable for cholesterol
X_test["chol_level"] = pd.cut(
    X_test["cholesterol"],
    bins=[-1, 10, 200, 240, 1000],
    labels=["imputed", "normal", "borderline", "high"]
)
y_test = test_df["heart_disease"].to_numpy()

# %%
# Preprocess the data
preprocessor = load(open("models/preprocessor.pkl", "rb"))

# %%
# Apply the preprocessor to the data
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
# Get the name of the transformed features
numeric_feature_names = preprocessor.named_transformers_[
    "numeric"
].get_feature_names_out()
categorical_feature_names = preprocessor.named_transformers_[
    "categorical"
].get_feature_names_out()
names = np.concatenate([numeric_feature_names, categorical_feature_names])
print(f"{names=}")
# Out:
# names=array(['age', 'resting_bp', 'cholesterol', 'max_hr', 'oldpeak', 'sex_F',
#        'sex_M', 'chest_pain_type_ASY', 'chest_pain_type_ATA',
#        'chest_pain_type_NAP', 'chest_pain_type_TA', 'fasting_bs_0',
#        'fasting_bs_1', 'resting_ecg_LVH', 'resting_ecg_Normal',
#        'resting_ecg_ST', 'exercise_angina_N', 'exercise_angina_Y',
#        'st_slope_Down', 'st_slope_Flat', 'st_slope_Up',
#        'chol_level_borderline', 'chol_level_high', 'chol_level_imputed',
#        'chol_level_normal'], dtype=object)

# %%
# Get the name of the transformed features
names_cleaned = [
    "Age",
    "Resting Blood Pressure",
    "Cholesterol",
    "Maximum Heart Rate",
    "Old Peak",
    "Sex Female",
    "Sex Male",
    "Chest Pain: Type Asymptomatic",
    "Chest Pain: Type Atypical Angina",
    "Chest Pain: Type Non-Anginal Pain",
    "Chest Pain: Type Typical Angina",
    "Fasting Blood Sugar < 120 mg/dl",
    "Fasting Blood Sugar > 120 mg/dl",
    "Resting ECG: Left Ventricular Hypertrophy",
    "Resting ECG: Normal",
    "Resting ECG: ST-T Wave Abnormality",
    "Exercise-Induced Angina: No",
    "Exercise-Induced Angina: Yes",
    "ST Slope: Downsloping",
    "ST Slope: Flat",
    "ST Slope: Upsloping",
    "Cholesterol Level: Borderline",
    "Cholesterol Level: High",
    "Cholesterol Level: Imputed",
    "Cholesterol Level: Normal"
]

# %%
# Create a dataframe with the transformed data
df_train = pd.DataFrame(data=X_train, columns=names_cleaned)

# %%
# Fit the model
Lasso = LogisticRegressionCV(cv=10, random_state=0).fit(df_train, y_train)

# %%
lambda_chosen = 1 / Lasso.C_[0]
lambda_chosen
# Out:
# 2.782559402207126

# %%
# Create a test dataframe with the transformed data
df_test = pd.DataFrame(data=X_test, columns=names_cleaned)
# Predict the target variable
y_pred = Lasso.predict(df_test)

# %%
# Compute the f1 score and the balanced accuracy
f1 = f1_score(y_test, y_pred)
bal_acc = balanced_accuracy_score(y_test, y_pred)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.826044226044226

# %%
print(f"Lasso model f1 score on training data: {f1}")
# Out:
# Lasso model f1 score on training data: 0.8660714285714286

# %%
print(classification_report(y_test, y_pred,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.814     0.770     0.792        74
#            1      0.851     0.882     0.866       110
#
#     accuracy                          0.837       184
#    macro avg      0.833     0.826     0.829       184
# weighted avg      0.836     0.837     0.836       184

# %%
print(f"Lasso model bal_acc score on training data: {bal_acc}")
# Out:
# Lasso model bal_acc score on training data: 0.826044226044226

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.826044226044226

# %%
roc_auc = roc_auc_score(y_test, y_pred)
print(f"Lasso auc value on training data: {roc_auc}")
# Out:
# Lasso auc value on training data: 0.826044226044226

# %%
roc_auc
# Out:
# 0.826044226044226

# %%
print(f"Lasso model score on training data: {Lasso.score(df_train, y_train)}")
print(f"Lasso model score on testing data: {Lasso.score(df_test, y_test)}")
# Out:
# Lasso model score on training data: 0.8908594815825375
# Lasso model score on testing data: 0.8369565217391305

# %%
# Metchin the coefficients with the feature names
coefs = pd.DataFrame(
    Lasso.coef_[0], columns=["Coefficients"], index=names_cleaned
)
coefs
# Out:
#                                            Coefficients
# Age                                            0.244930
# Resting Blood Pressure                         0.048403
# Cholesterol                                   -0.324452
# Maximum Heart Rate                            -0.089785
# Old Peak                                       0.493382
# Sex Female                                    -0.728503
# Sex Male                                       0.724588
# Chest Pain: Type Asymptomatic                  1.104704
# Chest Pain: Type Atypical Angina              -0.711024
# Chest Pain: Type Non-Anginal Pain             -0.382697
# Chest Pain: Type Typical Angina               -0.014898
# Fasting Blood Sugar < 120 mg/dl               -0.353480
# Fasting Blood Sugar > 120 mg/dl                0.349565
# Resting ECG: Left Ventricular Hypertrophy      0.099599
# Resting ECG: Normal                            0.026514
# Resting ECG: ST-T Wave Abnormality            -0.130028
# Exercise-Induced Angina: No                   -0.440401
# Exercise-Induced Angina: Yes                   0.436486
# ST Slope: Downsloping                         -0.133436
# ST Slope: Flat                                 1.147343
# ST Slope: Upsloping                           -1.017822
# Cholesterol Level: Borderline                 -0.395186
# Cholesterol Level: High                        0.225391
# Cholesterol Level: Imputed                     0.628281
# Cholesterol Level: Normal                     -0.462401

# %%
coefs_sorted = coefs.iloc[coefs.Coefficients.abs().argsort()[::-1]]
plt.figure(figsize=(10, 10))
coefs_sorted.plot(kind="bar")
plt.xticks(range(len(coefs_sorted)), coefs_sorted.index, rotation=90)
plt.ylabel("Coefficient")
plt.title("")

plt.savefig("lasso_coefficients.png", bbox_inches="tight")

# %%
# plot roc curve
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
fpr, tpr, thresholds = roc_curve(y_test, Lasso.predict_proba(X_test)[:,1])
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
# write the AUC in the plot
plt.annotate(f"AUC = {roc_auc:.2f}", (0.6, 0.4))

plt.show()
# Out:
# /home/janhsc/miniconda3/envs/ml4hc/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegressionCV was fitted with feature names
#   warnings.warn(

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Application of permutation importance, All the reference can be found: https://scikit-learn.org/stable/modules/permutation_importance.html
from sklearn.inspection import permutation_importance
r = permutation_importance(Lasso, df_test, y_test,
                           n_repeats=100,
                           random_state=0)

for i in r.importances_mean.argsort()[::-1]:
    print(f"{names_cleaned[i]:<8}"
          f"{r.importances_mean[i]:.3f}"
          f" +/- {r.importances_std[i]:.3f}")
# Out:
# ST Slope: Flat0.015 +/- 0.014
# ST Slope: Upsloping0.013 +/- 0.013
# Chest Pain: Type Asymptomatic0.012 +/- 0.010
# Cholesterol0.011 +/- 0.010
# Fasting Blood Sugar > 120 mg/dl0.010 +/- 0.006
# Fasting Blood Sugar < 120 mg/dl0.010 +/- 0.006
# Cholesterol Level: Imputed0.007 +/- 0.007
# Old Peak0.007 +/- 0.014
# Age     0.004 +/- 0.008
# Exercise-Induced Angina: Yes0.004 +/- 0.006
# Exercise-Induced Angina: No0.004 +/- 0.006
# Chest Pain: Type Non-Anginal Pain0.004 +/- 0.005
# Maximum Heart Rate0.003 +/- 0.004
# Chest Pain: Type Atypical Angina0.002 +/- 0.006
# Cholesterol Level: Borderline0.001 +/- 0.005
# Resting Blood Pressure0.000 +/- 0.001
# ST Slope: Downsloping0.000 +/- 0.000
# Chest Pain: Type Typical Angina0.000 +/- 0.000
# Resting ECG: ST-T Wave Abnormality0.000 +/- 0.000
# Resting ECG: Normal0.000 +/- 0.000
# Resting ECG: Left Ventricular Hypertrophy0.000 +/- 0.000
# Cholesterol Level: Normal-0.001 +/- 0.005
# Sex Female-0.003 +/- 0.008
# Sex Male-0.003 +/- 0.008
# Cholesterol Level: High-0.003 +/- 0.005

# %%
# Calculate means and standard deviations
means = r.importances_mean
sds = r.importances_std

# %%
sorted_indices = means.argsort()
means_sorted = means[sorted_indices]
sds_sorted = sds[sorted_indices]
names_cleaned_sorted = [names_cleaned[i] for i in sorted_indices]

# %%
plt.figure(figsize=(10, 6))
plt.errorbar(means_sorted, range(len(means_sorted)), xerr=sds_sorted, fmt='o', color='royalblue', ecolor='black', capsize=10)
plt.yticks(range(len(names_cleaned_sorted)), names_cleaned_sorted)
plt.xlabel('Values')
plt.title('Mean and Standard Deviation')
plt.tight_layout()

plt.savefig("lasso_permutation_importance.png")
